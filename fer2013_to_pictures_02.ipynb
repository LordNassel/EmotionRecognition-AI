# %%
"""
File:fer2013_to_pictures_02.py
Author: Gabor Levai
Email: levaigabor.net@gmail.com
Description: Emotion recognition with CNN
"""
import pandas as pd
import numpy as np
#matplotlib inline
import matplotlib.pyplot as plt
'''
datasource = pd.read_csv("fer2013.csv")
print ("The number of traning set samples: {}".format(len(datasource)))
'''
#%%
data0 = pd.read_csv("fer0.csv", sep=';')
print ("The number of traning set samples: {}".format(len(data0)))
print ("Training dataset emotion and its count")
data0.emotion.value_counts()
#%%
data1 = pd.read_csv("fer1.csv", sep=';')
print ("The number of traning set samples: {}".format(len(data1)))
#%%
data2 = pd.read_csv("fer2.csv", sep=';')
print ("The number of traning set samples: {}".format(len(data2)))
#%%
data3 = pd.read_csv("fer3.csv", sep=';')
print ("The number of traning set samples: {}".format(len(data3)))
#%%
data4 = pd.read_csv("fer4.csv", sep=';')
print ("The number of traning set samples: {}".format(len(data4)))
#%%
data5 = pd.read_csv("fer5.csv", sep=';')
print ("The number of traning set samples: {}".format(len(data5)))
#%%
data6 = pd.read_csv("fer6.csv", sep=';')
print ("The number of traning set samples: {}".format(len(data6)))
#%%
def Plot_SomeEmotion_Sample_Randomly3(emotion, dataset):
    #select certain emotion sub dataset
    EmotionSet = dataset[dataset.emotion == emotion]
    #randomly select one sample
    pixels_list = EmotionSet.sample(1).pixels.str.split(" ").tolist()
    #convert to 48*48 format
    show_image = np.array(pixels_list, dtype=float).reshape(48,48)
    #plot the image
    plt.imshow(show_image, cmap='gray')
    plt.savefig("happy"+ str(emotion) + ".png")
#%%
def Plot_SomeEmotion_Sample_Randomly4(emotion, dataset):
    #select certain emotion sub dataset
    EmotionSet = dataset[dataset.emotion == emotion]
    #randomly select one sample
    pixels_list = EmotionSet.sample(1).pixels.str.split(" ").tolist()
    #convert to 48*48 format
    show_image = np.array(pixels_list, dtype=float).reshape(48,48)
    #plot the image
    plt.imshow(show_image, cmap='gray')
    plt.savefig("sad"+ str(emotion) + ".png")
#%%
def Plot_SomeEmotion_Sample_Randomly5(emotion, dataset):
    #select certain emotion sub dataset
    EmotionSet = dataset[dataset.emotion == emotion]
    #randomly select one sample
    pixels_list = EmotionSet.sample(1).pixels.str.split(" ").tolist()
    #convert to 48*48 format
    show_image = np.array(pixels_list, dtype=float).reshape(48,48)
    #plot the image
    plt.imshow(show_image, cmap='gray')
    plt.savefig("surprise"+ str(emotion) + ".png")
#%%
def Plot_SomeEmotion_Sample_Randomly6(emotion, dataset):
    #select certain emotion sub dataset
    EmotionSet = dataset[dataset.emotion == emotion]
    #randomly select one sample
    pixels_list = EmotionSet.sample(1).pixels.str.split(" ").tolist()
    #convert to 48*48 format
    show_image = np.array(pixels_list, dtype=float).reshape(48,48)
    #plot the image
    plt.imshow(show_image, cmap='gray')
    plt.savefig("neutral"+ str(emotion) + ".png")
#%%
#plot randomly angry image
x=1
while (x < 541):
    Plot_SomeEmotion_Sample_Randomly3(x, data3)
    Plot_SomeEmotion_Sample_Randomly4(x, data4)
    Plot_SomeEmotion_Sample_Randomly5(x, data5)
    Plot_SomeEmotion_Sample_Randomly6(x, data6)
    x+=1
